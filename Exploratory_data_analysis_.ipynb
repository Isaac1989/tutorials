# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
titanic=pd.read_csv('https://raw.githubusercontent.com/Isaac1989/exploratory_data_analysis/master/titanic-train.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.describe()
# Out:
# C:\Users\senatoduro8\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3403: RuntimeWarning: Invalid value encountered in median
#   RuntimeWarning)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# ...

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.columns=titanic.columns.str.lower()
titanic.columns
# Out:
# Index(['passengerid', 'survived', 'pclass', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
#Row selection 

titanic.ix[1]
# Out:
# passengerid                                                    2
# survived                                                       1
# pclass                                                         1
# name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# sex                                                       female
# age                                                           38
# sibsp                                                          1
# parch                                                          0
# ticket                                                  PC 17599
# fare                                                     71.2833
# cabin                                                        C85
# embarked                                                       C
# Name: 1, dtype: object

# %%
x = pd.DataFrame({'x': [1, 2, 3], 'y': [3, 4, 5]})
x.iloc[1]=={'x':9,'y':99}
# Out:
#    x  y
# 0  1  3
# 1  2  4
# 2  3  5

# %%
titanic[titanic.survived==0].name.head()
# Out:
# 0           Braund, Mr. Owen Harris
# 4          Allen, Mr. William Henry
# 5                  Moran, Mr. James
# 6           McCarthy, Mr. Timothy J
# 7    Palsson, Master. Gosta Leonard
# Name: name, dtype: object

# %%
titanic[(titanic.fare<40 )& (titanic.pclass == 3)].name.head()
# Out:
# 0           Braund, Mr. Owen Harris
# 2            Heikkinen, Miss. Laina
# 4          Allen, Mr. William Henry
# 5                  Moran, Mr. James
# 7    Palsson, Master. Gosta Leonard
# Name: name, dtype: object

# %%
titanic[titanic.passengerid==675].name
# Out:
# 674    Watson, Mr. Ennis Hastings
# Name: name, dtype: object

# %%
(titanic.survived==1).sum()  #survived
# Out:
# 342

# %%
(titanic.survived==0).sum()  #died
titanic.shape[0]-342
# Out:
# 549

# %%
pd.crosstab(titanic.survived,titanic.sex)
# Out:
# sex       female  male
# survived
# 0             81   468
# 1            233   109

# %%
titanic[titanic.survived==1].fare.mean()
# Out:
# 48.39540760233917

# %%
titanic[titanic.survived==0].fare.mean()
# Out:
# 22.117886885245877

# %%
import seaborn as sns
# %matplotlib inline
titanic.age.plot(figsize=(8,8),kind='kde')

# %%
titanic.survived.plot(kind='pie')
